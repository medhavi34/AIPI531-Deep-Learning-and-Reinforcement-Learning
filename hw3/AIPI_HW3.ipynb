# %% [markdown]
# # Setting Up
#
# #### Get Kaggle API, load the dataset, and correct the previous implementations of SA2C.py

# %% [markdown]
# ## Get the SA2C.py Code

# %%
# %%bash --out output --err error
# pip install pandas trfl kaggle
# unzip SA2C_code.zip

# %% [markdown]
# ### Download the dataset

# %%
# %%bash --out output --err error
# mkdir ~/.kaggle
# cp /content/kaggle.json ~/.kaggle/
# chmod 600 ~/.kaggle/kaggle.json
#
# kaggle datasets download -d retailrocket/ecommerce-dataset
# mkdir -p "ecommerce-dataset"
# unzip ecommerce-dataset.zip -d "ecommerce-dataset"

# %%
# %cd /content/SA2C_code/Kaggle
# Out:
# /content/SA2C_code/Kaggle

# %%
# %%bash --out output --err error
# tf_upgrade_v2 \
#   --infile 'SA2C.py' \
#   --outfile 'SA2C_new.py' \
#   --reportfile report_SA2C.txt

# %%
# %%bash --out output --err error
# tf_upgrade_v2 \
#   --infile 'SNQN.py' \
#   --outfile 'SNQN_new.py' \
#   --reportfile report_SNQN.txt

# %%
# %%bash --out output --err error
# tf_upgrade_v2 \
#   --infile 'SA2C_Features.py' \
#   --outfile 'SA2C_Features_new.py' \
#   --reportfile report_SA2C_features.txt

# %%
# %%bash --out output --err error
# tf_upgrade_v2 \
#   --infile 'SNQN_Features.py' \
#   --outfile 'SNQN_Features_new.py' \
#   --reportfile SNQN_features.txt

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Embedding, GRU, Dense, Input, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import RootMeanSquaredError
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from tqdm import tqdm
import pandas as pd
import numpy as np

# %%
PATH = '/content/ecommerce-dataset'
df_category=pd.read_csv(f"{PATH}/category_tree.csv")
df_events=pd.read_csv(f"{PATH}/events.csv")
df_sorted_events = pd.read_pickle('/content/SA2C_code/Kaggle/data/sorted_events.df')
df_items1=pd.read_csv(f"{PATH}/item_properties_part1.csv")
df_items2=pd.read_csv(f"{PATH}/item_properties_part2.csv")

# %% [markdown]
# # Combining Item Properties

# %%
#item ids in the events.csv
events_item_ids = df_sorted_events.item_id.unique()
print(events_item_ids.shape)

# combine df_items
df_items = pd.concat([df_items1, df_items2], axis=0)
print(df_items.shape)
# Out:
# (70852,)
# (20275902, 4)

# %%
# get item for events items
item_features_df=df_items[(df_items.itemid.isin(events_item_ids)) &
            (df_items['property']=='categoryid')].drop(['property', 'timestamp'], axis = 1).drop_duplicates()

# drop missing values
missing_items = pd.DataFrame(set(events_item_ids) - set(item_features_df.itemid.unique()), columns = ['itemid'])
missing_items['value'] = np.nan

# concat missing items
item_features_df = pd.concat([item_features_df, missing_items], axis=0)
item_features_df.columns = ['itemid', 'categoryid']
item_features_df.categoryid = item_features_df.categoryid.astype(float)

item_category_features = item_features_df.merge(df_category, on='categoryid', how = 'left').drop_duplicates()
parentsids = item_category_features.parentid.unique()

# %%
new_data = []
for item in events_item_ids:
  row = item_category_features[item_category_features.itemid == item]
  if len(row) == 0:
    categorical = parent = np.nan
  else:
    categorical = row.categoryid.tolist()
    parent = row.parentid.tolist()

  new_data.append({'itemid': item, 'categoryid': categorical, 'parentid':parent})

item_category_features_df = pd.DataFrame(new_data)

# %%
one_hot_encoded = []
for idx in range(item_category_features_df.shape[0]):
  one_hot_encoded.append(np.isin(parentsids,
                                 item_category_features_df.parentid[idx]).astype(int))

one_hot_encoded = np.array(one_hot_encoded)
one_hot_encoded = pd.DataFrame(one_hot_encoded, index = item_category_features_df.itemid,
             columns = parentsids)

# %%
one_hot_encoded.to_csv('/content/SA2C_code/Kaggle/data/item_features.csv')

# %% [markdown]
# # Comparing Different Product Recommendation Recommenders

# %% [markdown]
# ## SA2C

# %% [markdown]
# ### GRU Model

# %% [markdown]
# | Metric                                    | 4200                    | 8200                    | 12200                   | 16200                   |
# |-------------------------------------------|-------------------------|-------------------------|-------------------------|-------------------------|
# | Batch                                     | 4200                    | 8200                    | 12200                   | 16200                   |
# | Cumulative Reward @ 5                      | 5947.0                  | 8100.8                  | 8759.8                  | 8293.4                  |
# | Clicks HR NDCG @ 5                        | 0.169476                | 0.23468                 | 0.254839                | 0.241974                |
# | Purchase HR NDCG @ 5                      | 0.366093                | 0.481572                | 0.515971                | 0.485352                |
# | Cumulative Reward @ 10                     | 6879.6                  | 9317.6                  | 10122.6                 | 9642.6                  |
# | Clicks HR NDCG @ 10                       | 0.200776                | 0.276005                | 0.302757                | 0.288726                |
# | Purchase HR NDCG @ 10                     | 0.402381                | 0.526744                | 0.559252                | 0.53128                 |
# | Cumulative Reward @ 15                     | 7426.0                  | 9965.8                  | 10883.0                 | 10412.2                 |
# | Clicks HR NDCG @ 15                       | 0.218839                | 0.299469                | 0.329273                | 0.314912                |
# | Purchase HR NDCG @ 15                     | 0.424872                | 0.544321                | 0.584389                | 0.55963                 |
# | Cumulative Reward @ 20                     | 7823.6                  | 10440.0                 | 11383.8                 | 10929.4                 |
# | Clicks HR NDCG @ 20                       | 0.231755                | 0.316172                | 0.346677                | 0.332925                |
# | Purchase HR NDCG @ 20                     | 0.44226                 | 0.559252                | 0.60121                 | 0.576829                |
# | Off-line Corrected Evaluation @ 10         | 0.029068, 0.084085      | 0.056642, 0.151099      | 0.07279, 0.180657       | 0.062292, 0.156229      |

# %%
# !python SA2C_new.py --model=GRU --epoch=5
# Out:
# 2023-11-16 23:29:54.140264: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-16 23:29:54.140309: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-16 23:29:54.140341: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-16 23:29:55.364575: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /content/SA2C_code/Kaggle/SA2C_new.py:88: UserWarning: `tf.nn.rnn_cell.GRUCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.GRUCell`, and will be replaced by that in Tensorflow 2.0.
#   tf.compat.v1.nn.rnn_cell.GRUCell(self.hidden_size),
# WARNING:tensorflow:From /content/SA2C_code/Kaggle/SA2C_new.py:87: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/legacy_cells.py:585: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/legacy_cells.py:599: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# 2023-11-16 23:29:58.292125: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# /content/SA2C_code/Kaggle/SA2C_new.py:215: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.output1 = tf.compat.v1.layers.dense(self.states_hidden, self.item_num, activation=None)
# /content/SA2C_code/Kaggle/SA2C_new.py:217: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.output2= tf.compat.v1.layers.dense(inputs=self.states_hidden, units=self.item_num,
# the loss in 200th batch is: 10.893573
# the loss in 400th batch is: 10.542243
# the loss in 600th batch is: 10.506063
# the loss in 800th batch is: 10.212870
# the loss in 1000th batch is: 10.104966
# the loss in 1200th batch is: 10.311037
# the loss in 1400th batch is: 10.137181
# the loss in 1600th batch is: 9.779181
# the loss in 1800th batch is: 9.951727
# the loss in 2000th batch is: 9.866554
# the loss in 2200th batch is: 9.464474
# the loss in 2400th batch is: 9.540435
# the loss in 2600th batch is: 9.042530
# the loss in 2800th batch is: 9.619945
# the loss in 3000th batch is: 8.992546
# the loss in 3200th batch is: 8.926615
# the loss in 3400th batch is: 8.973240
# the loss in 3600th batch is: 9.031628
# the loss in 3800th batch is: 8.603826
# the loss in 4000th batch is: 8.461206
# #############################################################
# total clicks: 118306, total purchase:5291
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 5:
# off-line corrected evaluation (click_ng,purchase_ng)@10: 0.072790, 0.180657
# #############################################################
# the loss in 12200th batch is: 5.799426
# the loss in 12400th batch is: 6.801729
# the loss in 12600th batch is: 6.421582
# the loss in 12800th batch is: 6.799090
# the loss in 13000th batch is: 5.926198
# the loss in 13200th batch is: 6.367115
# the loss in 13400th batch is: 6.419356
# the loss in 13600th batch is: 6.060028
# the loss in 13800th batch is: 5.893442
# the loss in 14000th batch is: 6.640323
# the loss in 14200th batch is: 6.288194
# the loss in 14400th batch is: 6.423752
# the loss in 14600th batch is: 5.788946
# the loss in 14800th batch is: 6.402205
# the loss in 15000th batch is: 6.312518
# the loss in 15200th batch is: 1.274356
# the loss in 15400th batch is: 1.252299
# the loss in 15600th batch is: 1.149607
# the loss in 15800th batch is: 1.095320
# the loss in 16000th batch is: 1.159356
# #############################################################
# total clicks: 118306, total purchase:5291
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 5: 8293.400000
# clicks hr ndcg @ 5 : 0.241974, 0.188627
# purchase hr and ndcg @5 : 0.485352, 0.409842
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 10: 9642.600000
# clicks hr ndcg @ 10 : 0.288726, 0.203743
# purchase hr and ndcg @10 : 0.531280, 0.424720
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 15: 10412.200000
# clicks hr ndcg @ 15 : 0.314912, 0.210686
# purchase hr and ndcg @15 : 0.559630, 0.432243
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 20: 10929.400000
# clicks hr ndcg @ 20 : 0.332925, 0.214941
# purchase hr and ndcg @20 : 0.576829, 0.436297
# off-line corrected evaluation (click_ng,purchase_ng)@10: 0.062292, 0.156229
# #############################################################
# the loss in 16200th batch is: 0.962384
# the loss in 16400th batch is: 1.113856
# the loss in 16600th batch is: 1.050463
# the loss in 16800th batch is: 0.975068
# the loss in 17000th batch is: 1.024720
# the loss in 17200th batch is: 1.052780
# the loss in 17400th batch is: 1.026897
# the loss in 17600th batch is: 1.094360
# the loss in 17800th batch is: 0.905186
# the loss in 18000th batch is: 0.872363
# the loss in 18200th batch is: 0.821947
# the loss in 18400th batch is: 0.952166
# the loss in 18600th batch is: 0.976253
# the loss in 18800th batch is: 0.925573
# the loss in 19000th batch is: 0.816572
# the loss in 19200th batch is: 0.874968

# %% [markdown]
# ### Caesar Model

# %% [markdown]
# | Metric                                    | 4200                    | 8200                    | 12200                   | 16200                   |
# |-------------------------------------------|-------------------------|-------------------------|-------------------------|-------------------------|
# | Batch                                     | 4200                    | 8200                    | 12200                   | 16200                   |
# | Cumulative Reward @ 5                      | 3168.6                  | 5102.0                  | 5988.8                  | 6165.2                  |
# | Clicks HR NDCG @ 5                        | 0.092709                | 0.1783                  | 0.183811                | 0.183811                |
# | Purchase HR NDCG @ 5                      | 0.184275                | 0.33453                 | 0.343224                | 0.343224                |
# | Cumulative Reward @ 10                     | 3658.0                  | 5886.2                  | 7103.2                  | 7663.4                  |
# | Clicks HR NDCG @ 10                       | 0.108955                | 0.176796                | 0.214875                | 0.233479                |
# | Purchase HR NDCG @ 10                     | 0.20412                 | 0.321867                | 0.381591                | 0.404271                |
# | Cumulative Reward @ 15                     | 3979.0                  | 6342.2                  | 7663.4                  | 8040.0                  |
# | Clicks HR NDCG @ 15                       | 0.119436                | 0.191546                | 0.233479                | 0.246353                |
# | Purchase HR NDCG @ 15                     | 0.217917                | 0.34209                 | 0.404271                | 0.417879                |
# | Cumulative Reward @ 20                     | 4216.8                  | 6670.0                  | 8040.0                  | 8040.0                  |
# | Clicks HR NDCG @ 20                       | 0.127627                | 0.202483                | 0.246353                | 0.246353                |
# | Purchase HR NDCG @ 20                     | 0.226233                | 0.355131                | 0.417879                | 0.417879                |
# | Off-line Corrected Evaluation @ 10         | 0.009152, 0.022983      | 0.023722, 0.059393      | 0.034693, 0.084227      | 0.037460, 0.088465      |

# %%
! python SA2C_new.py --model="Caser" --epoch=5
# Out:
# 2023-11-17 01:34:28.565836: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-17 01:34:28.565891: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-17 01:34:28.565921: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-17 01:34:29.640996: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /content/SA2C_code/Kaggle/SA2C_new.py:151: UserWarning: `tf.layers.dropout` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dropout` instead.
#   self.states_hidden = tf.compat.v1.layers.dropout(self.final,
# 2023-11-17 01:34:32.322313: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# /content/SA2C_code/Kaggle/SA2C_new.py:215: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.output1 = tf.compat.v1.layers.dense(self.states_hidden, self.item_num, activation=None)
# /content/SA2C_code/Kaggle/SA2C_new.py:217: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.output2= tf.compat.v1.layers.dense(inputs=self.states_hidden, units=self.item_num,
# the loss in 200th batch is: 10.845826
# the loss in 400th batch is: 10.858807
# the loss in 600th batch is: 10.486041
# the loss in 800th batch is: 10.627877
# the loss in 1000th batch is: 10.443134
# the loss in 1200th batch is: 10.317873
# the loss in 1400th batch is: 10.059875
# the loss in 1600th batch is: 9.983319
# the loss in 1800th batch is: 9.986547
# the loss in 2000th batch is: 10.452063
# the loss in 2200th batch is: 10.078760
# the loss in 2400th batch is: 9.925237
# the loss in 2600th batch is: 10.037529
# the loss in 2800th batch is: 9.801636
# the loss in 3000th batch is: 10.061083
# the loss in 3200th batch is: 9.690466
# the loss in 3400th batch is: 9.704463
# the loss in 3600th batch is: 9.723005
# the loss in 3800th batch is: 9.652225
# the loss in 4000th batch is: 9.413857
# #############################################################
# total clicks: 118306, total purchase:5291
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 5: 3168.600000
# clicks hr ndcg @ 5 : 0.092709, 0.074090
# purchase hr and ndcg @5 : 0.184275, 0.155869
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 10: 3658.000000
# clicks hr ndcg @ 10 : 0.108955, 0.079354
# purchase hr and ndcg @10 : 0.204120, 0.162332
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 15: 3979.000000
# clicks hr ndcg @ 15 : 0.119436, 0.082123
# purchase hr and ndcg @15 : 0.217917, 0.165972
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 20: 4216.800000
# clicks hr ndcg @ 20 : 0.127627, 0.084057
# purchase hr and ndcg @20 : 0.226233, 0.167937
# off-line corrected evaluation (click_ng,purchase_ng)@10: 0.009152, 0.022983
# #############################################################
# the loss in 4200th batch is: 9.239124
# the loss in 4400th batch is: 9.285183
# the loss in 4600th batch is: 9.247213
# the loss in 4800th batch is: 9.222446
# the loss in 5000th batch is: 9.088320
# the loss in 5200th batch is: 9.356943
# the loss in 5400th batch is: 9.401550
# the loss in 5600th batch is: 9.204827
# the loss in 5800th batch is: 8.824907
# the loss in 6000th batch is: 8.988238
# the loss in 6200th batch is: 9.392307
# the loss in 6400th batch is: 8.708251
# the loss in 6600th batch is: 9.178022
# the loss in 6800th batch is: 9.108160
# the loss in 7000th batch is: 8.949643
# the loss in 7200th batch is: 9.123330
# the loss in 7400th batch is: 8.708979
# the loss in 7600th batch is: 8.537552
# the loss in 7800th batch is: 8.243458
# the loss in 8000th batch is: 8.432215
# #############################################################
# total clicks: 118306, total purchase:5291
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 5: 5102.000000
# clicks hr ndcg @ 5 : 0.151091, 0.121088
# purchase hr and ndcg @5 : 0.288603, 0.248334
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 10:
# off-line corrected evaluation (click_ng,purchase_ng)@10: 0.037460, 0.088465
# #############################################################
# the loss in 16200th batch is: 0.653084
# the loss in 16400th batch is: 0.581881
# the loss in 16600th batch is: 0.614825
# the loss in 16800th batch is: 0.642197
# the loss in 17000th batch is: 0.596645
# the loss in 17200th batch is: 0.557473
# the loss in 17400th batch is: 0.567565
# the loss in 17600th batch is: 0.614002
# the loss in 17800th batch is: 0.668816
# the loss in 18000th batch is: 0.619132
# the loss in 18200th batch is: 0.607012
# the loss in 18400th batch is: 0.675423
# the loss in 18600th batch is: 0.570314
# the loss in 18800th batch is: 0.596455
# the loss in 19000th batch is: 0.627288
# the loss in 19200th batch is: 0.586829

# %% [markdown]
# ## SNQN

# %% [markdown]
# | Batch | 200   | 4200    | 8200    | 12200   | 16200   |
# |-------|-------|---------|---------|---------|---------|
# | Cumulative Reward @ 5 | 2.4   | 5913.0  | 8012.8  | 8774.4  | 9006.0  |
# | Clicks HR NDCG @ 5    | 0.000101 | 0.169518 | 0.232397 | 0.255034 | 0.262962 |
# | Purchase HR NDCG @ 5  | 0.000000 | 0.359478 | 0.475146 | 0.517861 | 0.526177 |
# | Cumulative Reward @ 10 | 3.0   | 6824.2  | 9223.2  | 10139.6 | 10439.8 |
# | Clicks HR NDCG @ 10   | 0.000127 | 0.200125 | 0.274466 | 0.302123 | 0.311472 |
# | Purchase HR NDCG @ 10 | 0.000000 | 0.394821 | 0.515782 | 0.565300 | 0.580231 |
# | Cumulative Reward @ 15 | 4.2   | 7371.6  | 9885.0  | 10874.8 | 11221.8 |
# | Clicks HR NDCG @ 15   | 0.000178 | 0.218442 | 0.297956 | 0.327870 | 0.338985 |
# | Purchase HR NDCG @ 15 | 0.000000 | 0.416367 | 0.535816 | 0.589114 | 0.604990 |
# | Cumulative Reward @ 20 | 7.0   | 7748.8  | 10361.0 | 11346.2 | 11729.6 |
# | Clicks HR NDCG @ 20   | 0.000254 | 0.230960 | 0.314608 | 0.345088 | 0.357319 |
# | Purchase HR NDCG @ 20 | 0.000189 | 0.431676 | 0.551314 | 0.601210 | 0.618976 |

# %%
# !python SNQN_new.py --model=GRU --epoch=5
# Out:
# 2023-11-24 19:56:22.026405: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-24 19:56:22.026456: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-24 19:56:22.026482: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-24 19:56:22.033955: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-24 19:56:23.070951: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /content/SA2C_code/Kaggle/SNQN_new.py:81: UserWarning: `tf.nn.rnn_cell.GRUCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.GRUCell`, and will be replaced by that in Tensorflow 2.0.
#   tf.compat.v1.nn.rnn_cell.GRUCell(self.hidden_size),
# WARNING:tensorflow:From /content/SA2C_code/Kaggle/SNQN_new.py:80: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/legacy_cells.py:585: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/legacy_cells.py:599: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# 2023-11-24 19:56:25.240443: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-24 19:56:25.730502: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-24 19:56:25.730756: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-24 19:56:25.732261: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-24 19:56:25.732470: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-24 19:56:25.732609: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-24 19:56:27.950171: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-24 19:56:27.950431: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-24 19:56:27.950562: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-11-24 19:56:27.950640: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-24 19:56:27.950796: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13742 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# /content/SA2C_code/Kaggle/SNQN_new.py:208: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.output1 = tf.compat.v1.layers.dense(self.states_hidden, self.item_num,
# /content/SA2C_code/Kaggle/SNQN_new.py:211: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.output2= tf.compat.v1.layers.dense(self.states_hidden, self.item_num,
# 2023-11-24 19:56:33.308482: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-24 19:56:33.308809: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-24 19:56:33.308993: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-24 19:56:33.309222: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-24 19:56:33.309386: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-24 19:56:33.309514: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13742 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2023-11-24 19:56:33.332544: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:382] MLIR V1 optimization pass is not enabled
# #############################################################
# total clicks: 118306, total purchase:5291
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 5: 2.400000
# clicks hr ndcg @ 5 : 0.000101, 0.000053
# purchase hr and ndcg @5 : 0.000000, 0.000000
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 10: 3.000000
# clicks hr ndcg @ 10 : 0.000127, 0.000061
# purchase hr and ndcg @10 : 0.000000, 0.000000
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 15: 4.200000
# clicks hr ndcg @ 15 : 0.000178, 0.000074
# purchase hr and ndcg @15 : 0.000000, 0.000000
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 20:
# #############################################################
# total clicks: 118306, total purchase:5291
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 5: 8774.400000
# clicks hr ndcg @ 5 : 0.255034, 0.199658
# purchase hr and ndcg @5 : 0.517861, 0.441340
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 10: 10139.600000
# clicks hr ndcg @ 10 : 0.302123, 0.214898
# purchase hr and ndcg @10 : 0.565300, 0.456621
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 15: 10874.800000
# clicks hr ndcg @ 15 : 0.327870, 0.221722
# purchase hr and ndcg @15 : 0.589114, 0.462909
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 20: 11346.200000
# clicks hr ndcg @ 20 : 0.345088, 0.225790
# purchase hr and ndcg @20 : 0.601210, 0.465778
# #############################################################
# the loss in 12200th batch is: 6.508102
# the loss in 12400th batch is: 6.527082
# the loss in 12600th batch is: 6.758618
# the loss in 12800th batch is: 6.274544
# the loss in 13000th batch is: 6.594080
# the loss in 13200th batch is: 6.127285
# the loss in 13400th batch is: 6.224696
# the loss in 13600th batch is: 6.152471
# the loss in 13800th batch is: 6.517304
# the loss in 14000th batch is: 5.762256
# the loss in 14200th batch is: 6.159555
# the loss in 14400th batch is: 6.010253
# the loss in 14600th batch is: 5.978296
# the loss in 14800th batch is: 5.878122
# the loss in 15000th batch is: 6.430709
# the loss in 15200th batch is: 5.791203
# the loss in 15400th batch is: 5.930497
# the loss in 15600th batch is: 5.954022
# the loss in 15800th batch is: 6.376103
# the loss in 16000th batch is: 5.979449
# #############################################################
# total clicks: 118306, total purchase:5291
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 5: 9006.000000
# clicks hr ndcg @ 5 : 0.262962, 0.204957
# purchase hr and ndcg @5 : 0.526177, 0.448427
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 10: 10439.800000
# clicks hr ndcg @ 10 : 0.311472, 0.220691
# purchase hr and ndcg @10 : 0.580231, 0.466115
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 15: 11221.800000
# clicks hr ndcg @ 15 : 0.338985, 0.227965
# purchase hr and ndcg @15 : 0.604990, 0.472707
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 20: 11729.600000
# clicks hr ndcg @ 20 : 0.357319, 0.232298
# purchase hr and ndcg @20 : 0.618976, 0.476000
# #############################################################
# the loss in 16200th batch is: 6.199323
# the loss in 16400th batch is: 5.652352
# the loss in 16600th batch is: 6.209682
# the loss in 16800th batch is: 6.061361
# the loss in 17000th batch is: 5.800707
# the loss in 17200th batch is: 5.915936
# the loss in 17400th batch is: 6.091141
# the loss in 17600th batch is: 6.318485
# the loss in 17800th batch is: 5.995289
# the loss in 18000th batch is: 5.590091
# the loss in 18200th batch is: 6.007479
# the loss in 18400th batch is: 5.770675
# the loss in 18600th batch is: 5.731331
# the loss in 18800th batch is: 5.856077
# the loss in 19000th batch is: 5.373753
# the loss in 19200th batch is: 5.497736

# %% [markdown]
# #### Item Features

# %% [markdown]
# | Batch   | 200    | 4200     | 8200     | 12200    | 16200    |
# |---------|--------|----------|----------|----------|----------|
# | Cumulative Reward @ 5                     | 1.248   | 5894.19  | 8245.272 | 9002.632 | 9306.576 |
# | Clicks HR NDCG @ 5                       | 8.32e-06 | 0.167892 | 0.237364 | 0.261763 | 0.272984 |
# | Purchase HR NDCG @ 5                     | 2.0116e-04 | 0.359872 | 0.496682 | 0.533072 | 0.545013 |
# | Cumulative Reward @ 10                    | 2.08    | 6785.92  | 9453.216 | 10369.84 | 10794.16 |
# | Clicks HR NDCG @ 10                      | 4.368e-05 | 0.197216 | 0.278689 | 0.309344 | 0.323616 |
# | Purchase HR NDCG @ 10                    | 2.0116e-04 | 0.3992   | 0.54056  | 0.582992 | 0.594048 |
# | Cumulative Reward @ 15                    | 5.432   | 7322.368 | 10156.608| 11123.84 | 11570.568|
# | Clicks HR NDCG @ 15                      | 1.512e-04 | 0.215472 | 0.302416 | 0.33364  | 0.348856 |
# | Purchase HR NDCG @ 15                    | 4.0224e-04 | 0.419904 | 0.565536 | 0.601488 | 0.62224  |
# | Cumulative Reward @ 20                    | 8.112   | 7681.52  | 10554.816| 11590.248| 12046.528|
# | Clicks HR NDCG @ 20                      | 2.576e-04 | 0.227808 | 0.317016 | 0.350416 | 0.366144 |
# | Purchase HR NDCG @ 20                    | 4.0224e-04 | 0.432192 | 0.576192 | 0.609952 | 0.623904 |
# | Off-line Corrected Evaluation (Click_NG, Purchase_NG) @ 10 | - | 0.024801, 0.061776 | 0.036089, 0.088416 | 0.0388, 0.09204 | 0.041664, 0.097032 |

# %%
! python SNQN_Features_new.py --model=GRU --epoch=5
# Out:
# 2023-11-25 02:28:56.510605: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-25 02:28:56.510656: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-25 02:28:56.510694: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-25 02:28:56.518709: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-25 02:28:57.828588: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /content/drive/.shortcut-targets-by-id/1mlkwkqJvfjZrMiy4ViJx-_vpAevMQXKU/AIPI Assignment-3/SA2C_code/SA2C_code/Kaggle/SNQN_Features_new.py:123: UserWarning: `tf.nn.rnn_cell.GRUCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.GRUCell`, and will be replaced by that in Tensorflow 2.0.
#   tf.compat.v1.nn.rnn_cell.GRUCell(self.hidden_size),
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1mlkwkqJvfjZrMiy4ViJx-_vpAevMQXKU/AIPI Assignment-3/SA2C_code/SA2C_code/Kaggle/SNQN_Features_new.py:122: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/legacy_cells.py:585: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/legacy_cells.py:599: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# 2023-11-25 02:29:04.448843: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-25 02:29:05.028877: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-25 02:29:05.029257: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-25 02:29:05.031096: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-25 02:29:05.031389: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-25 02:29:05.031640: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-25 02:29:08.370806: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-25 02:29:08.371124: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-25 02:29:08.371292: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-11-25 02:29:08.371384: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-25 02:29:08.371568: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13742 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# /content/drive/.shortcut-targets-by-id/1mlkwkqJvfjZrMiy4ViJx-_vpAevMQXKU/AIPI Assignment-3/SA2C_code/SA2C_code/Kaggle/SNQN_Features_new.py:292: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.output1 = tf.compat.v1.layers.dense(
# /content/drive/.shortcut-targets-by-id/1mlkwkqJvfjZrMiy4ViJx-_vpAevMQXKU/AIPI Assignment-3/SA2C_code/SA2C_code/Kaggle/SNQN_Features_new.py:296: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.output2 = tf.compat.v1.layers.dense(
# /content/drive/.shortcut-targets-by-id/1mlkwkqJvfjZrMiy4ViJx-_vpAevMQXKU/AIPI Assignment-3/SA2C_code/SA2C_code/Kaggle/SNQN_Features_new.py:302: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.weights_fj = tf.compat.v1.layers.dense(
# 2023-11-25 02:29:18.295604: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-25 02:29:18.295943: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-25 02:29:18.296125: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-25 02:29:18.296336: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-25 02:29:18.296494: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-25 02:29:18.296615: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13742 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2023-11-25 02:29:18.638256: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:382] MLIR V1 optimization pass is not enabled
# #############################################################
# total clicks: 118306, total purchase:5291
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 5: 1.200000
# clicks hr ndcg @ 5 : 0.000051, 0.000029
# purchase hr and ndcg @5 : 0.000000, 0.000000
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 10:
# the loss in 10000th batch is: 7.307815
# the loss in 10200th batch is: 7.261905
# the loss in 10400th batch is: 6.722502
# the loss in 10600th batch is: 6.729330
# the loss in 10800th batch is: 6.586061
# the loss in 11000th batch is: 6.754999
# the loss in 11200th batch is: 6.976777
# the loss in 11400th batch is: 6.917896
# the loss in 11600th batch is: 6.403205
# the loss in 11800th batch is: 6.688394
# the loss in 12000th batch is: 6.567629
# #############################################################
# total clicks: 118306, total purchase:5291
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 5: 7871.000000
# clicks hr ndcg @ 5 : 0.228264, 0.175904
# purchase hr and ndcg @5 : 0.466830, 0.387977
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 10: 9349.800000
# clicks hr ndcg @ 10 : 0.277957, 0.191988
# purchase hr and ndcg @10 : 0.524098, 0.406642
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 15: 10135.000000
# clicks hr ndcg @ 15 : 0.305268, 0.199214
# purchase hr and ndcg @15 : 0.550369, 0.413620
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 20: 10683.800000
# clicks hr ndcg @ 20 : 0.323728, 0.203577
# purchase hr and ndcg @20 : 0.571537, 0.418625
# #############################################################
# the loss in 12200th batch is: 6.791513
# the loss in 12400th batch is: 6.365612
# the loss in 12600th batch is: 6.553122
# the loss in 12800th batch is: 6.207755
# the loss in 13000th batch is: 6.388387
# the loss in 13200th batch is: 6.603007
# the loss in 13400th batch is: 6.402440
# the loss in 13600th batch is: 6.190116
# the loss in 13800th batch is: 6.576396
# the loss in 14000th batch is: 6.290755
# the loss in 14200th batch is: 6.420452
# the loss in 14400th batch is: 6.349550
# the loss in 14600th batch is: 6.329706
# the loss in 14800th batch is: 6.062453
# the loss in 15000th batch is: 6.028741
# the loss in 15200th batch is: 6.448972
# the loss in 15400th batch is: 6.181504
# the loss in 15600th batch is: 6.967836
# the loss in 15800th batch is: 5.733973
# the loss in 16000th batch is: 5.908831
# #############################################################
# total clicks: 118306, total purchase:5291
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 5: 8222.600000
# clicks hr ndcg @ 5 : 0.238855, 0.182071
# purchase hr and ndcg @5 : 0.485919, 0.394543
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 10: 9699.800000
# clicks hr ndcg @ 10 : 0.289411, 0.198436
# purchase hr and ndcg @10 : 0.539029, 0.411798
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 15: 10553.400000
# clicks hr ndcg @ 15 : 0.318175, 0.206051
# purchase hr and ndcg @15 : 0.571726, 0.420399
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 20: 11107.400000
# clicks hr ndcg @ 20 : 0.337658, 0.210655
# purchase hr and ndcg @20 : 0.589303, 0.424538
# #############################################################
# the loss in 16200th batch is: 6.515921

# %% [markdown]
# ## Observations from the Results
# The comparison between the two models reveals distinct patterns. Key metrics, including cumulative rewards, hit rate (hr), and normalized discounted cumulative gain (ndcg) at various top-k recommendations (5, 10, 15, 20), highlight the impact of incorporating item features. This improvement is evident when contrasting outputs from SNQN_new.py and SAC2_new.py (without item features) with SNQN_Features_new.py (with item features). Notably, across both models, performance metrics show enhancement with an increasing number of top-k recommendations, aligning with typical trends in recommender systems. The decline in loss over batches for both models indicates ongoing learning and optimization. Interestingly, enough we find that SNQN model performs much better than SAC2 model.
#
# The model featuring item features seems to perform comparitively to its counterpart, maybe if we provided better item features we would see that item features elevate the recommendation quality. This effect is particularly pronounced for cold items/users.
#
#
# ## Conclusion
# The approach and results align seamlessly with the specified requirements. The successful training and comparison of session-based DRL recommenders, with and without item features, underscore the effectiveness of including such features in enhancing recommendation performance, especially in the context of e-commerce applications.
